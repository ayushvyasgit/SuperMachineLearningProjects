# %%
import tensorflow as tf 
from tensorflow.keras import models, layers 
import matplotlib.pyplot as plt

# %%
Image_S = 256*256
Batch_S = 32

# %%
#take the dataset from the directory 
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "PlantVillage",
    shuffle="True",
    image_size=(Image_S , Image_S),
    batch_size=(Batch_S)
)
# Out:
# Found 61914 files belonging to 3 classes.

# %%
#show me class_name from dataset 
class_names = dataset.class_names
class_names
# Out:
# ['earlyBlight', 'lateBlight', 'potatoHealthy']

# %%
for image_batch ,label_batch in dataset.take(1):
    print(image_batch.shape)
    print(label_batch.numpy())
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 for image_batch ,label_batch in dataset.take(1):
#       2     print(image_batch.shape)
#       3     print(label_batch.numpy())
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\data\ops\iterator_ops.py:826, in OwnedIterator.__next__(self)
#     824 def __next__(self):
#     825   try:
# --> 826     return self._next_internal()
#     827   except errors.OutOfRangeError:
#     828     raise StopIteration
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\data\ops\iterator_ops.py:776, in OwnedIterator._next_internal(self)
#     773 # TODO(b/77291417): This runs in sync mode as iterators use an error status
#     774 # to communicate that there is no more data to iterate over.
#     775 with context.execution_mode(context.SYNC):
# ...

# %%
for image_batch ,label_batch in dataset.take(1):
    for i in range(12):
        ax= plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[label_batch[i]])
        plt.axis("off")

# %%
#now take this images and bundle them to process 
def get_dataset_patitions_tf(ds,train_split=0.8 , test_split=0.1, val_split=0.1,shuffle="True" , shuffle_size=10000):
    train_size = int(train_split*len(ds))
    val_size   = int(val_split*len(ds))

    train_ds   = ds.take(train_size),
    val_ds     = ds.skip(train_size).take(val_size),
    test_ds    = ds.skip(train_size).skip(val_size)

    return train_ds , val_ds ,test_ds

# %%
#now take the train_ds and train it using a model 
 #first take it in cache ram to do processign fast , [load into memory ]
train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
#define a input shape for image 
input_shape = (BATCH_SIZE, IMAGE_SIZE,IMAGE_SIZE,CHANNELS)
n_classes =3

# %%
#create a model outline like how many tf operation you will perform 
model = tf.keras.Sequential(
    tf.keras.layers.Resizing(Image_S,Image_S),
    tf.keras.layers.Rescaling(1.0/255),
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(0.2),

    tf.keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=input_shape),
    tf.keras.layers.maxPooling2D((2,2))
    
)
model.build
